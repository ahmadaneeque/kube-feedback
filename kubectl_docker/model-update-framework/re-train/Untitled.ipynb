# %%
import json

def read_logs(uid):
    history = []
    with open(file_name) as reader:
        line = reader.readline().split('->')[-1]
        val = json.loads(line)
        if uid == val.get('name'):
            history.append(val)

# %%
import os

# %%
os.listdir()
# Out:
# ['tasks',
#  'mlog.py',
#  'app-thread.py',
#  'app.log',
#  'main.py',
#  '.ipynb_checkpoints',
#  '__pycache__',
#  'Dockerfile',
#  'app.py',
#  'app.ini',
#  '.idea',
#  'test.py',
#  'training_model.py',
#  'Untitled.ipynb']

# %%
# with open('readme.txt') as f:
#     lines = f.readlines()

# %%
file_name = 'app.log'
# read_logs('anomaly_4e9e94095d6e6a517dfa')
history = []
with open('app.log') as reader:
    lines = reader.readlines()
    for line in lines:
        print(line)
#         val = 
#         val = json.loads(line.split('->')[-1])
        
#     pri
#     if uid == val.get('name'):
#         history.append(val)
# Out:
# 2021-03-10 10:48:22,937 ->Started
#
# 2021-03-10 10:48:22,944 ->{"name": "anomaly_48fd8459f38d3692ba1f", "status": "in progress", "operation": "Data loading"}
#
# 2021-03-10 10:48:49,874 ->Exception on /status/anomaly_4234bbffb4d4c1b8dc11 [GET]
#
# Traceback (most recent call last):
#
#   File "/home/ahmad/anaconda3/envs/modelupdate/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#
#     response = self.full_dispatch_request()
#
#   File "/home/ahmad/anaconda3/envs/modelupdate/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#
#     rv = self.handle_user_exception(e)
#
#   File "/home/ahmad/anaconda3/envs/modelupdate/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#
#     reraise(exc_type, exc_value, tb)
#
#   File "/home/ahmad/anaconda3/envs/modelupdate/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#
#     raise value
#
# ...

# %%
import sqlalchemy

# sqlalchemy.__version__
# from sqlalchemy import create_engine
# engine = create_engine('sqlite:///college.db', echo=True)
# # dialect[+driver]://user:password@host/dbname
# engine.connect()

from sqlalchemy import (create_engine, MetaData,
                        Table, Column, String,
                        Binary, ARRAY, BIGINT)


sql_alchemy_conn_str = "postgresql://postgres:somePassword@localhost:5432/postgres"

engine = create_engine(sql_alchemy_conn_str, echo=False)

meta = MetaData()

ml_model = Table(
    'spool_table', meta,
    Column('uid', String, primary_key=True),
    Column('status', String),
    Column('operation', String),
    Column("location", String),

    # Column('class', String),
    # Column('model', Binary),
    # Column('owner', String),
    # Column('description', String),
    # Column('timestamp', BIGINT),
)
# custom_log.write_log(uid, 'completed', operation='Model saved', location=temp_storage)


def return_model_table_name():
    meta.create_all(engine)
    return 'spool_table'


def wirte_enery():
    pass

def read_enery():
    pass

def foo():
    pass

if __name__ == '__main__':
    print('hello')
# Out:
# hello

# %%
# import sqlalchemy

meta.create_all(engine)

# %%
meta
# Out:
# MetaData(bind=None)
